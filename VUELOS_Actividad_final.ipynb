# %% [markdown]
# ## ACTIVIDAD FINAL: Vuelos

# %%
#Importamos la librerias que usaremos para la limpieza y analisis de datos.

import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('C:/Users/Adm1n/Maestria_EAN/Actividad final/Vuelos/business.csv',parse_dates=['date'])  # Asignamos a la variable df1 para el dataframe de business

# %%
df2=pd.read_csv('C:/Users/Adm1n/Maestria_EAN/Actividad final/Vuelos/economy.csv',parse_dates=['date']) # Asignamos a la variable df2 para el dataframe de business

# %% [markdown]
# ## Empezamos a limpiar el data frame de la linea de negocios -business

# %%
df1
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
# ...

# %%
df1['Type']='Business' # Creamos una columna que asigne todos los valores del df1 a "Business"

# %%
df1
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
# ...

# %%
df2
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df2['Type']='Economy' #Creamos una columna que asigne todos los valores del df2 a "Economy"
df2
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %% [markdown]
# Concatenamos ambas listas mediante la función .concat() mediante axis=0 por que vamos a unir las tablas una debajo de la otra. No usamos merge por que no tienen datos en relación. Ya que cada fila representa una persona que pago in ticket para viajar de una ciudad a otra.
#
# Este nuevo dataframe es asignada a la variable df3

# %%
df3 = pd.concat([df1,df2],axis=0)
df3
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df3.info() #Como podemos observar la columna 'price' esta como variable tipo str, cuando esta deberia ser tipo float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300261 entries, 0 to 206773
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  object
#  11  Type        300261 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 29.8+ MB

# %%
df3[df3['num_code']==544] #Como podemos observar cada linea representa un viajero distinto con la 
                          #unica distinción es realmente del precio que llego a costarle el tiquete.
# Out:
#              date    airline ch_code  num_code dep_time    from time_taken  \
# 4      11-02-2022  Air India      AI       544    17:15   Delhi    06h 40m
# 56     12-02-2022  Air India      AI       544    17:15   Delhi    06h 40m
# 148    13-02-2022  Air India      AI       544    17:15   Delhi    06h 40m
# 243    14-02-2022  Air India      AI       544    17:15   Delhi    06h 40m
# 361    15-02-2022  Air India      AI       544    17:15   Delhi    06h 40m
# ...           ...        ...     ...       ...      ...     ...        ...
# 62110  15-02-2022     Indigo      6E       544    13:55  Mumbai    09h 00m
# 62399  17-02-2022     Indigo      6E       544    13:55  Mumbai    09h 00m
# 62794  19-02-2022     Indigo      6E       544    13:55  Mumbai    09h 00m
# 63311  22-02-2022     Indigo      6E       544    13:55  Mumbai    09h 00m
# 63957  26-02-2022     Indigo      6E       544    13:55  Mumbai    09h 00m
#
# ...

# %% [markdown]
# Convertimos los datos de la columna a tipo entero (int), pero primero debemos reemplazar la ',' y quitar espacios para poder lograrlo.

# %%
df3['price']=df3['price'].str.replace(',','').str.replace(' ','')
df3['price']=df3['price'].astype(int)

df3
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300261 entries, 0 to 206773
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  int32
#  11  Type        300261 non-null  object
# dtypes: int32(1), int64(1), object(10)
# memory usage: 28.6+ MB

# %% [markdown]
# Con este arreglo ya podemos generar un analisis estadistico para la variable "price" mediante la función .describe()

# %%
df3[df3['Type']=='Economy']['price'].describe()
# Out:
# count    206774.000000
# mean       6571.190701
# std        3743.442838
# min        1105.000000
# 25%        4173.000000
# 50%        5772.000000
# 75%        7746.000000
# max       42349.000000
# Name: price, dtype: float64

# %%
df3[df3['Type']=='Business']['price'].describe()
# Out:
# count     93487.000000
# mean      52540.081124
# std       12969.314606
# min       12000.000000
# 25%       45185.000000
# 50%       53164.000000
# 75%       60396.000000
# max      123071.000000
# Name: price, dtype: float64

# %% [markdown]
# Del anterior analisis podemos concluir lo siguiente:
# - Se compraron 206.774 tiquetes en tipo economico y 93.487 tiquetes en tipo negocios. Aproximadamente por cada tiquete tipo Business se compraron 2.2 tiquetes Economy.
# - En promedio la diferencia entre el precio de business y economy es de 45.969 rupias. Esto es pesos colombianos es aproximadamente $2.276.432

# %% [markdown]
# # Limpieza de columna stop

# %%
df3['stop'].value_counts() #Observamos que tienen multiplos caracteres que no permiten el entendimiento de los datos.
# Out:
# stop
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t                      243603
# non-stop                                                                         36044
# 2+-stop                                                                          13288
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\t\t\t\t\t\t\t\t\t\t                 1839
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IDR\n\t\t\t\t\t\t\t\t\t\t\t\t                 1398
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Patna\n\t\t\t\t\t\t\t\t\t\t\t\t                674
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Indore\n\t\t\t\t\t\t\t\t\t\t\t\t               381
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia PAT\n\t\t\t\t\t\t\t\t\t\t\t\t                  354
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia MYQ\n\t\t\t\t\t\t\t\t\t\t\t\t                  321
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Bhubaneswar\n\t\t\t\t\t\t\t\t\t\t\t\t          301
# 1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia KLH\n\t\t\t\t\t\t\t\t\t\t\t\t                  284
# ...

# %% [markdown]
# Mediante la función .replace() realizamos la limpieza de la columna "stop"

# %%
df3['stop']=df3['stop'].str.replace('\n','')
df3['stop']=df3['stop'].str.replace('\t','')
df3['stop']=df3['stop'].str.replace('1-stopVia','')
df3['stop']=df3['stop'].str.replace('1-stop','Una Escala')
df3['stop']=df3['stop'].str.replace('non-stop','Directo')
df3['stop']=df3['stop'].str.replace('2+-stop','Dos Escalas')

df3
# Out:
#               date    airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1       11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2       11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3       11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4       11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...            ...        ...     ...       ...      ...      ...        ...
# 206769  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022    Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %% [markdown]
# # Limpieza columna date y volverla tipo datetime.

# %%
df3['date'].unique()
# Out:
# array(['11-02-2022', '12-02-2022', '13-02-2022', '14-02-2022',
#        '15-02-2022', '16-02-2022', '17-02-2022', '18-02-2022',
#        '19-02-2022', '20-02-2022', '21-02-2022', '22-02-2022',
#        '23-02-2022', '24-02-2022', '25-02-2022', '26-02-2022',
#        '27-02-2022', '28-02-2022', '01-03-2022', '02-03-2022',
#        '03-03-2022', '04-03-2022', '05-03-2022', '06-03-2022',
#        '07-03-2022', '08-03-2022', '09-03-2022', '10-03-2022',
#        '11-03-2022', '12-03-2022', '13-03-2022', '14-03-2022',
#        '15-03-2022', '16-03-2022', '17-03-2022', '18-03-2022',
#        '19-03-2022', '20-03-2022', '21-03-2022', '22-03-2022',
#        '23-03-2022', '24-03-2022', '25-03-2022', '26-03-2022',
#        '27-03-2022', '28-03-2022', '29-03-2022', '30-03-2022',
#        '31-03-2022'], dtype=object)

# %%
df3.info() # Como podemos observar es un tipo str la columna date
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300261 entries, 0 to 206773
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  int32
#  11  Type        300261 non-null  object
# dtypes: int32(1), int64(1), object(10)
# memory usage: 28.6+ MB

# %%
df3['date']=pd.to_datetime(df3['date'], format = '%d-%m-%Y') # Convertimos la columna 'date' en variable datetime.
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300261 entries, 0 to 206773
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  datetime64[ns]
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  int32
#  11  Type        300261 non-null  object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(9)
# memory usage: 28.6+ MB

# %%
#Separamos el datetime esto con el proposito de darle mayor analisis mediante las graficas.

# %%
df3['Year']=df3['date'].apply(lambda x:x.year)
df3['Month']=df3['date'].apply(lambda x:x.month)
df3['Day']=df3['date'].apply(lambda x:x.day)

df3
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      2022-02-11  Air India      AI       868    18:00    Delhi    02h 00m
# 1      2022-02-11  Air India      AI       624    19:00    Delhi    02h 15m
# 2      2022-02-11  Air India      AI       531    20:00    Delhi    24h 45m
# 3      2022-02-11  Air India      AI       839    21:25    Delhi    26h 30m
# 4      2022-02-11  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 206769 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771 2022-03-31    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772 2022-03-31    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773 2022-03-31    Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df3
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      2022-02-11  Air India      AI       868    18:00    Delhi    02h 00m
# 1      2022-02-11  Air India      AI       624    19:00    Delhi    02h 15m
# 2      2022-02-11  Air India      AI       531    20:00    Delhi    24h 45m
# 3      2022-02-11  Air India      AI       839    21:25    Delhi    26h 30m
# 4      2022-02-11  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 206769 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206770 2022-03-31    Vistara      UK       832    07:05  Chennai    13h 50m
# 206771 2022-03-31    Vistara      UK       826    12:30  Chennai    20h 35m
# 206772 2022-03-31    Vistara      UK       822    09:45  Chennai    23h 20m
# 206773 2022-03-31    Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300261 entries, 0 to 206773
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  datetime64[ns]
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  int32
#  11  Type        300261 non-null  object
#  12  Year        300261 non-null  int64
#  13  Month       300261 non-null  int64
#  14  Day         300261 non-null  int64
# dtypes: datetime64[ns](1), int32(1), int64(4), object(9)
# memory usage: 35.5+ MB

# %% [markdown]
# ## Visualización de datos (datetime)

# %%
sns.set_theme()

# %%
vental_total=df3.groupby('airline')['price'].sum()
vental_total
# Out:
# airline
# Air India    1901546720
# AirAsia        65858089
# GO FIRST      130994795
# Indigo        229580207
# SpiceJet       55681482
# StarAir          300892
# Trujet           133030
# Vistara      3886470735
# Name: price, dtype: int64

# %%
# Grafica precio venta por aerolinia
vental_total=df3.groupby('airline')['price'].sum()

vental_total.plot(kind='barh')

plt.xlabel('Venta total')
plt.ylabel('Aerolinea')
plt.title('Ventas totales por Aerolinea')


plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# La aerolinia que mas vendio fue Vistara generando incluso mas del doble de ventas totales que la segunda aerolinea Air India.

# %%
# Grafica precio venta por aerolinia
sns.countplot(x=df3['airline'],data=df3, hue='Type')
# Out:
# <Axes: xlabel='airline', ylabel='count'>

# %%
aerolinea_totaltype=df3.groupby('airline')['Type'].value_counts()
aerolinea_totaltype
# Out:
# airline    Type
# Air India  Economy     47996
#            Business    32898
# AirAsia    Economy     16098
# GO FIRST   Economy     23177
# Indigo     Economy     43120
# SpiceJet   Economy      9011
# StarAir    Economy        61
# Trujet     Economy        41
# Vistara    Economy     67270
#            Business    60589
# Name: count, dtype: int64

# %% [markdown]
# Como podemos observar las unicas aerolineas que vendieron el tipo de tiquete 'Business' son; 'Air India' & 'Vistara'

# %%
# Grafica Destino con ventas totales mas altas

venta_destino=df3.groupby('to')['price'].sum()

venta_destino.plot(kind='barh')

plt.xlabel('Venta total')
plt.ylabel('Destino')
plt.title('Ventas totales por Destino')


plt.grid()
plt.tight_layout()
plt.show()

# %%
#Grafica destino con mas cantidad de tiquetes vendidos por tipo.
sns.countplot(x=df3['to'],data=df3, hue='Type')
# Out:
# <Axes: xlabel='to', ylabel='count'>

# %%
venta_destino=df3.groupby('to')['price'].sum()
venta_destino
# Out:
# to
# Bangalore    1102899875
# Chennai       886211782
# Delhi        1057539137
# Hyderabad     873062658
# Kolkata      1087749901
# Mumbai       1263102597
# Name: price, dtype: int32

# %%
df3[df3['to']=='Bangalore'].describe()
# Out:
#                                 date      num_code          price     Year  \
# count                          51112  51112.000000   51112.000000  51112.0
# mean   2022-03-08 01:08:58.112380928   1317.687901   21578.100544   2022.0
# min              2022-02-11 00:00:00    101.000000    1443.000000   2022.0
# 25%              2022-02-25 00:00:00    651.000000    4721.000000   2022.0
# 50%              2022-03-08 00:00:00    824.000000    7425.000000   2022.0
# 75%              2022-03-20 00:00:00    940.000000   44144.000000   2022.0
# max              2022-03-31 00:00:00   9937.000000  114523.000000   2022.0
# std                              NaN   1812.866510   23267.690411      0.0
#
#               Month           Day
# count  51112.000000  51112.000000
# mean       2.665519     17.413367
# min        2.000000      1.000000
# 25%        2.000000     12.000000
# 50%        3.000000     18.000000
# 75%        3.000000     24.000000
# max        3.000000     31.000000
# ...

# %%
df3[df3['to']=='Delhi'].describe()
# Out:
#                                 date      num_code          price     Year  \
# count                          57361  57361.000000   57361.000000  57361.0
# mean   2022-03-08 04:16:57.973884928   1528.237653   18436.553355   2022.0
# min              2022-02-11 00:00:00    102.000000    2051.000000   2022.0
# 25%              2022-02-25 00:00:00    631.000000    4439.000000   2022.0
# 50%              2022-03-08 00:00:00    822.000000    6521.000000   2022.0
# 75%              2022-03-20 00:00:00    878.000000   32923.000000   2022.0
# max              2022-03-31 00:00:00   9931.000000  123071.000000   2022.0
# std                              NaN   2125.086637   20485.612968      0.0
#
#               Month           Day
# count  57361.000000  57361.000000
# mean       2.670089     17.415945
# min        2.000000      1.000000
# 25%        2.000000     12.000000
# 50%        3.000000     18.000000
# 75%        3.000000     24.000000
# max        3.000000     31.000000
# ...

# %% [markdown]
# Podemos observar que que Mumbai es el destino que mas visitan y por consiguiente el que mas ventas totales genera.
#
# Sucede algo interesante entre Bangalore y Delhi. Como podemos observar la siguiente situación:
#
# -Delhi
# Tiene una cantidad de tiquetes vendidos de 57.361 con un costo promedio de 18.436 para un total aproximado de 1.057.507.396
# -Bangalore
# Tiene una cantidad de tiquetes vendidos de 51.112 con un costo promedio de 21.578 para un total aproximado de 1.102.894.736
#
# Por lo tanto, Bangalore es el segundo destino que genera mas ventas pero Delhi es el segundo destino que mas visitan.

# %%
# Grafica Tipo con ventas mas altas.

labels=['Business','Economy']
sizes=[df3[df3['Type']=='Business']['price'].sum(),df3[df3['Type']=='Economy']['price'].sum()]

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribucion ventas totales por tipo')

plt.show()

# %%
# Grafica Tipo con ventas mas altas.

cantidad_tipo=df3.groupby('Type')['Type'].value_counts()
cantidad_tipo.plot(kind='bar')

plt.xlabel('Tipo')
plt.ylabel('Cantidad')
plt.title('Viajeros totales por Tipo')

plt.xticks(rotation=0)
plt.grid()
plt.tight_layout()
plt.show()

# %%
df3['Type'].value_counts()
# Out:
# Type
# Economy     206774
# Business     93487
# Name: count, dtype: int64

# %%
ventas_mes=df3.groupby('Month')['price'].sum()

ventas_mes.plot(kind='bar')
plt.title('Ventas totales por mes')
plt.xticks(rotation=0)
plt.show()

# %%
#Grafica cantidad de tiquetes vendidos en el mes por tipo.
sns.countplot(x=df3['Month'],data=df3, hue='Type')
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
sns.histplot(data=df3,y='airline',hue='Month')
# Out:
# <Axes: xlabel='Count', ylabel='airline'>

# %%
df3[df3['Month']==2].describe()
# Out:
#                                 date       num_code          price      Year  \
# count                         100589  100589.000000  100589.000000  100589.0
# mean   2022-02-20 08:48:11.481176064    1412.605434   23835.836791    2022.0
# min              2022-02-11 00:00:00     101.000000    1105.000000    2022.0
# 25%              2022-02-16 00:00:00     640.000000    7425.000000    2022.0
# 50%              2022-02-21 00:00:00     819.000000   12045.000000    2022.0
# 75%              2022-02-25 00:00:00     927.000000   44405.000000    2022.0
# max              2022-02-28 00:00:00    9991.000000  123071.000000    2022.0
# std                              NaN    1965.732811   22421.985702       0.0
#
#           Month           Day
# count  100589.0  100589.00000
# mean        2.0      20.36680
# min         2.0      11.00000
# 25%         2.0      16.00000
# 50%         2.0      21.00000
# 75%         2.0      25.00000
# max         2.0      28.00000
# ...

# %%
df3[df3['Month']==3].describe()
# Out:
#                                 date       num_code          price      Year  \
# count                         199672  199672.000000  199672.000000  199672.0
# mean   2022-03-15 21:10:29.159822336    1420.374329   19396.525116    2022.0
# min              2022-03-01 00:00:00     101.000000    1105.000000    2022.0
# 25%              2022-03-08 00:00:00     636.000000    4249.000000    2022.0
# 50%              2022-03-16 00:00:00     818.000000    6067.000000    2022.0
# 75%              2022-03-24 00:00:00     927.000000   41281.000000    2022.0
# max              2022-03-31 00:00:00    9974.000000  105638.000000    2022.0
# std                              NaN    1978.923413   22687.681095       0.0
#
#           Month            Day
# count  199672.0  199672.000000
# mean        3.0      15.882282
# min         3.0       1.000000
# 25%         3.0       8.000000
# 50%         3.0      16.000000
# 75%         3.0      24.000000
# max         3.0      31.000000
# ...

# %% [markdown]
# El mes de marzo se realizo casi el doble de cantidad de ventas que en el mes de febrero. No obstante, el mes de febrero se realizaron ventas de tiquetes mas caros que en marzo.

# %%
sns.displot(df3.price, color='blue')

# %% [markdown]
# Del grafico anterior podemos concluir que la mayor cantidad de tiquetes que se vendieron fueron inferiores a 20.000 rupias

# %%
#Que ciudad de origen se usa mas se usa mas
sns.countplot(x=df3['from'],data=df3, hue='airline')
# Out:
# <Axes: xlabel='from', ylabel='count'>

# %%
df3[df3['Month']==2].describe()
# Out:
#                                 date       num_code          price      Year  \
# count                         100589  100589.000000  100589.000000  100589.0
# mean   2022-02-20 08:48:11.481176064    1412.605434   23835.836791    2022.0
# min              2022-02-11 00:00:00     101.000000    1105.000000    2022.0
# 25%              2022-02-16 00:00:00     640.000000    7425.000000    2022.0
# 50%              2022-02-21 00:00:00     819.000000   12045.000000    2022.0
# 75%              2022-02-25 00:00:00     927.000000   44405.000000    2022.0
# max              2022-02-28 00:00:00    9991.000000  123071.000000    2022.0
# std                              NaN    1965.732811   22421.985702       0.0
#
#           Month           Day
# count  100589.0  100589.00000
# mean        2.0      20.36680
# min         2.0      11.00000
# 25%         2.0      16.00000
# 50%         2.0      21.00000
# 75%         2.0      25.00000
# max         2.0      28.00000
# ...

# %%
#Que aeropuerto se usa mas
sns.countplot(x=df3['to'],data=df3, hue='Type')
# Out:
# <Axes: xlabel='to', ylabel='count'>

# %%
df3['stop'].unique()
# Out:
# array(['Directo ', 'Una Escala', ' IDR', ' IXU', ' Chennai', ' Lucknow',
#        ' STV', ' Hyderabad', ' GAY', 'Dos Escalas', ' Guwahati', ' GAU',
#        ' VTZ', ' NDC', ' IXE', ' Raipur', ' PAT', ' RPR', ' Patna',
#        ' Kolkata', ' HYD', ' Delhi', ' Bhubaneswar', ' BBI', ' Surat',
#        ' Indore', ' GOP', ' Nagpur', ' NAG', ' Vishakhapatnam',
#        ' Mangalore', ' Mumbai', ' KLH', ' MYQ', ' Kolhapur', ' JRG',
#        ' Ranchi', ' IXR', ' JGB', ' Mysore'], dtype=object)
